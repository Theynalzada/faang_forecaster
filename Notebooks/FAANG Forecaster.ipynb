# %% [markdown]
# # FAANG Forecaster

# %%
# Importing Dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import faang_utils
import warnings
import pickle

# %%
sns.set(font_scale = 1.5, style = "darkgrid", palette = "bright")
warnings.filterwarnings(action = "ignore")
plt.rcParams["figure.figsize"] = (18, 8)
pd.options.display.max_columns = None
np.random.seed(seed = 42)

# %% [markdown]
# Let's call function to forecast the closing stock price of the next seven days.

# %%
# Creating a list of Initial Public Offerings (IPO)
ipos = ["Meta", "Amazon", "Apple", "Netflix", "Google"]

# Looping through each IPO
for i in ipos:
    # Calling the function to forecast the closing stock price of the next seven days
    faang_utils.forecast_closing_stock_prices(ipo_name = i)
